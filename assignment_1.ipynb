# %% [markdown]
# Area of a circle

# %%
radius = float(input("enter the radius of the circle whose area youd like to find:"))
print(f'The area of the circle is :{float(math.pi*radius**2)}')
# Out:
# enter the radius of the circle whose area youd like to find:2.3
# the area of the circle is :16.619025137490002

# %% [markdown]
# Area of a traingle

# %%
base = float(input("enter the base of the triangle whose area youd like to find:"))
height = float(input("enter the height of the triangle whose area youd like to find:"))
print(f'The area of a triangle is:{float(0.5*base*height)}')
# Out:
# enter the base of the triangle whose area youd like to find:5
# enter the height of the triangle whose area youd like to find:7
# The area of a triangle is:17.5
